# %%
import pandas as pd
data = pd.read_csv('altered_data.csv')

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                              id  Age       covid_status record_date  \
# 0  XbOUJCUl8GWEpQpIRMvujDE1sTE2   57  positive_moderate   17-Jul-21
# 1  Qcliznd3z1VdWmJOZh9nvlstTYv1   47  positive_moderate   17-Jul-21
# 2  EaZfxkcnIWgsPfPW2XfFTjh7GQk2   61  positive_moderate   19-Jul-21
# 3  DqztVX8gWrOi4il3xouSTV4FwyC3   43      positive_mild   16-Jul-21
# 4  G5wWAa7nvkOR9QvfsAt7tsd5qa82   55  positive_moderate   17-Jul-21
#
#   English_proficiency  Gender Country    Locality       State  Returning User  \
# 0                   n  female   India  Coimbatore  Tamil Nadu           False
# 1                   y    male   India  Coimbatore  Tamil Nadu           False
# 2                   y    male   India  Coimbatore  Tamil Nadu           False
# 3                   y    male   India  Coimbatore  Tamil Nadu           False
# 4                   y    male   India  Coimbatore  Tamil Nadu           False
#
#    ...  cough  ctScan  testType  test_date test_status  Mask vaccination  \
# ...
